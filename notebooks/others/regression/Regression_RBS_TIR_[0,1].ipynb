# %% [markdown]
# # Regression on RBS sequences - Escherichia coli - Predict TIR
#
# This notebook shows the regression of RBS sequences.
#
# There are several parts of the implementation.
#
# - Reading the dataset
# - Embedding
#     - Label
#     - One-hot embedding
#     - K-mer
#     - PMW (to be added)
#     - Unsupervised (to be added)
# - Kernels
#     - Spectrum
#     - Mixed Spectrum
#     - Weighted Degree
#     - Weighted Degree with Shifting
# - Evaluate
#     - RMSE score
#     - Plot

# %%
# direct to proper path
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import itertools
from collections import defaultdict

from codes.embedding import Embedding
from codes.environment import Rewards_env
from codes.ucb import GPUCB
from codes.evaluations import evaluate, plot_eva
from codes.regression import Regression
from codes.kernels_pairwise import spectrum_kernel_pw, sum_spectrum_kernel_pw, sum_onehot_spectrum_kernel_pw, mixed_spectrum_kernel_pw, WD_kernel_pw, sum_onehot_WD_kernel_pw, WD_shift_kernel_pw

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import PairwiseKernel, DotProduct, RBF
from sklearn.kernel_ridge import KernelRidge

from ipywidgets import IntProgress
from IPython.display import display
import warnings
# %matplotlib inline

# %% [markdown]
# ## Reading the Dataset

# %%
# Data downloaded from https://github.com/synbiochem/opt-mva
# Paper https://pubs.acs.org/doi/abs/10.1021/acssynbio.8b00398

# A: whole RBS sequence (len: 29)
# B: extracted 20-base RBS seqeunce (A[7:27], len: 20), training features
# C: TIR labels
# D: the design part RBS (B[7:13], len: 6) 

Path = '../../data/RBS_seqs.csv'

df = pd.read_csv(Path)
df.columns = ['A', 'B', 'C']
df['D'] = df['B'].str[7:13]
df.head()
# Out:
#                                A                     B      C       D
# 0  ACGATCTTAAGTAAGCGGGGAAAATAATG  TTAAGTAAGCGGGGAAAATA  57706  AGCGGG
# 1  ACGATCTTAAGTAGACGCGGAAAATAATG  TTAAGTAGACGCGGAAAATA    613  GACGCG
# 2  ACGATCTTAAGTAAGCGCGGAAAATAATG  TTAAGTAAGCGCGGAAAATA   5313  AGCGCG
# 3  ACGATCTTAAGTAAACGAGGAAAATAATG  TTAAGTAAACGAGGAAAATA  19594  AACGAG
# 4  ACGATCTTAAGTAGGCGAGGAAAATAATG  TTAAGTAGGCGAGGAAAATA  33626  GGCGAG

# %%
# drop the exact same record (same B and C)

df = df.drop_duplicates(subset = ['B', 'C'])
df.shape
# Out:
# (113, 4)

# %%
Log_flag = False # indicates whether take log label
Norm_method = 'minmax' # indicates how to normalize label (one of 'mean', 'minmax', None)

def normalize(df):
    # take log FC -- possiblely provide Gaussain distribution?
    if Log_flag:
        df['C'] = np.log(df['C'])
    if Norm_method == 'mean':
        # mean normalization
        df['C'] = (df['C'] - df['C'].mean())/df['C'].std()
    elif Norm_method == 'minmax':
        # min-max normalization 
        df['C'] = (df['C'] - df['C'].min())/(df['C'].max() - df['C'].min())
    else:
        assert Norm_method == None
        
    return df

# %%
# data: num_data * 2, columns: [20-base RBS seq (B), TIR labels (C)]
data = np.asarray(normalize(df)[['B', 'C']])
data.shape
# Out:
# (113, 2)

# %%
plt.hist(data[:,1])
# Out:
# (array([59., 18., 14.,  5.,  4.,  1.,  5.,  3.,  1.,  3.]),
#  array([0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001,
#         0.7000000000000001, 0.8, 0.9, 1.0], dtype=object),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Regression
#
# - Kernel Ridge Regression
# - Gaussian Process Regression

# %%
# indicates whether cross validation (KFOLD)
cross_val_flag = False 

# indicates whether plot predict_label vs. true label
plot_flag = True 

# string kernel list 
# kernels = [spectrum_kernel_pw, mixed_spectrum_kernel_pw, WD_kernel_pw, WD_shift_kernel_pw]
kernels = [sum_onehot_spectrum_kernel_pw, sum_onehot_WD_kernel_pw]

# name dictionaries
regression_name = {KernelRidge: 'KR',
                  GaussianProcessRegressor: 'GPR'}
embedding_name = ['onehot', 'kmer', 'label']
kernel_name = {
               spectrum_kernel_pw: 'spec',
               sum_spectrum_kernel_pw: 'sspec',
               sum_onehot_spectrum_kernel_pw: 'sospec',
               mixed_spectrum_kernel_pw: 'mspec',
               WD_kernel_pw: 'WD',
               sum_onehot_WD_kernel_pw: 'sWD',
               WD_shift_kernel_pw: 'WDshift'}

train_scores = {}
test_scores = {}

# %%
def run_regression(model, kernel, embedding):
    if model == KernelRidge:
        reg = Regression(model(kernel = kernel), data, embedding)
    elif model == GaussianProcessRegressor:
        reg = Regression(model(kernel = PairwiseKernel(metric = kernel)), data, embedding)
    reg.train()
    train_score, test_score = reg.evaluate(cross_val_flag = cross_val_flag, plot_flag = plot_flag, metric = 'r2_score')
    key = regression_name[model] + '_' + kernel_name[kernel] + '_' + embedding
    train_scores[key] = train_score
    test_scores[key] = test_score
    print()

for model in [KernelRidge, GaussianProcessRegressor]:
    for kernel in kernels:
        run_regression(model, kernel, 'label')
# Out:
# Model:  KernelRidge(alpha=1, coef0=1, degree=3, gamma=None,
#             kernel=<function sum_onehot_spectrum_kernel_pw at 0x7fe76e904510>,
#             kernel_params=None)
# Train r2_score: 0.44778314190763846
# Test r2_score: -0.2546056648026884
#
# Model:  KernelRidge(alpha=1, coef0=1, degree=3, gamma=None,
#             kernel=<function sum_onehot_WD_kernel_pw at 0x7fe76e9046a8>,
#             kernel_params=None)
# Train r2_score: 0.48111802759566
# Test r2_score: 0.04767253942568772
#
# Model:  GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#                          kernel=PairwiseKernel(gamma=1.0, metric=<function sum_onehot_spectrum_kernel_pw at 0x7fe76e904510>),
#                          n_restarts_optimizer=0, normalize_y=False,
#                          optimizer='fmin_l_bfgs_b', random_state=None)
# Train r2_score: 0.5131709575945905
# Test r2_score: -0.014906274092735039
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ce7d9a3ca6ed> in <module>
#      13 for model in [KernelRidge, GaussianProcessRegressor]:
#      14     for kernel in kernels:
# ---> 15         run_regression(model, kernel, 'label')
#
# <ipython-input-9-ce7d9a3ca6ed> in run_regression(model, kernel, embedding)
#       4     elif model == GaussianProcessRegressor:
#       5         reg = Regression(model(kernel = PairwiseKernel(metric = kernel)), data, embedding)
# ----> 6     reg.train()
#       7     train_score, test_score = reg.evaluate(cross_val_flag = cross_val_flag, plot_flag = plot_flag, metric = 'r2_score')
#       8     key = regression_name[model] + '_' + kernel_name[kernel] + '_' + embedding
#
# ~/git/SynbioML/codes/regression.py in train(self)
#      90         """
#      91         self.model.fit(self.X_train, self.Y_train)
# ---> 92         self.train_predict = self.model.predict(self.X_train)
#      93         self.test_predict = self.model.predict(self.X_test)
#      94
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py in predict(self, X, return_std, return_cov)
#     319                 return y_mean
#     320         else:  # Predict based on GP posterior
# --> 321             K_trans = self.kernel_(X, self.X_train_)
#     322             y_mean = K_trans.dot(self.alpha_)  # Line 4 (y_mean = f_star)
#     323             y_mean = self._y_train_mean + y_mean  # undo normal.
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py in __call__(self, X, Y, eval_gradient)
#    1832         K = pairwise_kernels(X, Y, metric=self.metric, gamma=self.gamma,
#    1833                              filter_params=True,
# -> 1834                              **pairwise_kernels_kwargs)
#    1835         if eval_gradient:
#    1836             if self.hyperparameter_gamma.fixed:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in pairwise_kernels(X, Y, metric, filter_params, n_jobs, **kwds)
#    1743         raise ValueError("Unknown kernel %r" % metric)
#    1744
# -> 1745     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1204
#    1205     if effective_n_jobs(n_jobs) == 1:
# -> 1206         return func(X, Y, **kwds)
#    1207
#    1208     # enforce a threading backend to prevent data communication overhead
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in _pairwise_callable(X, Y, metric, **kwds)
#    1248         iterator = itertools.product(range(X.shape[0]), range(Y.shape[0]))
#    1249         for i, j in iterator:
# -> 1250             out[i, j] = metric(X[i], Y[j], **kwds)
#    1251
#    1252     return out
#
# ~/git/SynbioML/codes/kernels_pairwise.py in sum_onehot_WD_kernel_pw(x, y, gamma, l)
#     387         for j in range(0, d2 - d + 1):
#     388             beta = 2 * float(l - d + 1)/float(l ** 2 + 1)
# --> 389             k+= beta * spectrum_kernel_pw(x2, y2, l = d, j_x = j, j_y = j, d = d)
#     390
#     391     return x1.dot(y1.T) + k + x3.dot(y3.T)
#
# ~/git/SynbioML/codes/kernels_pairwise.py in spectrum_kernel_pw(x, y, gamma, l, j_x, j_y, d)
#     114     # sequence cannot pass the check
#     115     # x, y = check_pairwise_arrays(x, y)
# --> 116     phi_x, phi_y = phi(x, y, l, j_x, j_y, d)
#     117     return phi_x.dot(phi_y.T)
#     118
#
# ~/git/SynbioML/codes/kernels_pairwise.py in phi(x, y, l, j_x, j_y, d)
#      50     cv = CountVectorizer(analyzer='word',token_pattern=u"(?u)\\b\\w+\\b")
#      51     #cv = CountVectorizer()
# ---> 52     embedded = cv.fit_transform(sentences).toarray()
#      53     #print(embedded)
#      54     scaled_embedded = scale(embedded)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1006         X = sp.csr_matrix((values, j_indices, indptr),
#    1007                           shape=(len(indptr) - 1, len(vocabulary)),
# -> 1008                           dtype=self.dtype)
#    1009         X.sort_indices()
#    1010         return vocabulary, X
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      68                     idx_dtype = get_index_dtype((indices, indptr),
#      69                                                 maxval=maxval,
# ---> 70                                                 check_contents=True)
#      71
#      72                     self.indices = np.array(indices, copy=copy,
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/sparse/sputils.py in get_index_dtype(arrays, maxval, check_contents)
#     140     """
#     141
# --> 142     int32min = np.iinfo(np.int32).min
#     143     int32max = np.iinfo(np.int32).max
#     144
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/getlimits.py in __init__(self, int_type)
#     501             self.dtype = numeric.dtype(type(int_type))
#     502         self.kind = self.dtype.kind
# --> 503         self.bits = self.dtype.itemsize * 8
#     504         self.key = "%s%d" % (self.kind, self.bits)
#     505         if self.kind not in 'iu':
#
# KeyboardInterrupt:

# %% [markdown]
# ### Kernel Ridge Regression

# %%
# Baseline: onehot embedding with DotProduct kernel

reg = Regression(KernelRidge(kernel = DotProduct()), data, 'onehot')
reg.train()
train_score, test_score = reg.evaluate(cross_val_flag = cross_val_flag)
train_scores['KR_onehot_DP'] = train_score
test_scores['KR_onehot_DP'] = test_score

# %%
# kmer embedding with DotProduct kernel (l = 3)

reg = Regression(KernelRidge(kernel = DotProduct()), data, 'kmer')
reg.train()
train_score, test_score = reg.evaluate(cross_val_flag = cross_val_flag)
train_scores['KR_kmer_DP'] = train_score
test_scores['KR_kmer_DP'] = test_score

# %% [markdown]
# ### Gaussian Process Regression

# %%
# # baseline: onehot embedding with DotProduct Kernel 
reg = Regression(GaussianProcessRegressor(kernel = DotProduct()), data, 'onehot')
reg.train()
train_score, test_score = reg.evaluate(cross_val_flag = cross_val_flag)
train_scores['GPR_onehot_DP'] = train_score
test_scores['GPR_onehot_DP'] = test_score

# %%
# kmer embedding (l = 3)
reg = Regression(GaussianProcessRegressor(kernel = DotProduct()), data, 'kmer')
reg.train()
train_score, test_score = reg.evaluate(cross_val_flag = cross_val_flag)
train_scores['GPR_kmer_DP'] = train_score
test_scores['GPR_kmer_DP'] = test_score

# %%
sorted_train_scores = sorted(train_scores.items(), key=lambda kv: kv[1])

import collections

sorted_train_scores = collections.OrderedDict(sorted_train_scores)

plt.bar(range(len(sorted_train_scores)), list(sorted_train_scores.values()), align='center')
plt.xticks(range(len(sorted_train_scores)), list(sorted_train_scores.keys()), rotation = 70)
plt.ylabel('RMSE')
plt.title('Train Scores')

# %%
sorted_test_scores = sorted(test_scores.items(), key=lambda kv: kv[1])

import collections

sorted_test_scores = collections.OrderedDict(sorted_test_scores)

plt.bar(range(len(sorted_test_scores)), list(sorted_test_scores.values()), align='center')
plt.xticks(range(len(sorted_test_scores)), list(sorted_test_scores.keys()), rotation = 70)
plt.ylabel('RMSE')
plt.title('Test Scores')

# %%
import pickle

#with open('sum_kernels.pickle', 'wb') as handle:
#    pickle.dump(sorted_test_scores, handle, protocol=pickle.HIGHEST_PROTOCOL)
