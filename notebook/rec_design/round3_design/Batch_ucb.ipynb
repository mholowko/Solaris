# %% [markdown]
# # Batch UCB

# %%
# direct to proper path
import os
import sys
module_path = os.path.abspath(os.path.join('../../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from collections import defaultdict
import math
import json

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import PairwiseKernel, DotProduct, RBF 
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score, mean_squared_error, make_scorer
from sklearn.model_selection import KFold
from sklearn_extra.cluster import KMedoids

from codes.embedding import Embedding
from codes.environment import Rewards_env
from codes.ucb import GPUCB, Random
from codes.evaluations import evaluate, plot_eva
from codes.regression import *
from codes.kernels_for_GPK import *
from codes.batch_ucb import *

from ipywidgets import IntProgress
from IPython.display import display
import warnings
# %matplotlib inline
# Out:
# /home/admin-u6015325/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /home/admin-u6015325/ownCloud/git/SynbioML/notebooks/rec_design/round3_design
# ['/home/admin-u6015325/ownCloud/git/SynbioML/notebooks/rec_design/round3_design', '/home/admin-u6015325/anaconda3/lib/python37.zip', '/home/admin-u6015325/anaconda3/lib/python3.7', '/home/admin-u6015325/anaconda3/lib/python3.7/lib-dynload', '', '/home/admin-u6015325/anaconda3/lib/python3.7/site-packages', '/home/admin-u6015325/anaconda3/lib/python3.7/site-packages/strkernel-0.2-py3.7.egg', '/home/admin-u6015325/anaconda3/lib/python3.7/site-packages/IPython/extensions', '/home/admin-u6015325/.ipython', '/home/admin-u6015325/ownCloud/git/SynbioML']

# %% [markdown]
# **Update 13/Nov/2020** Generate recommendation for round 2 (with partial replicates for round 0 and 1)

# %%
norm_method = 'mean'
log_flag = 'True'
Path = '../../../data/Results_Microplate_partialTrue_normTrue_' + norm_method+ '_roundRep_formatSeq_log' + log_flag + '.csv'

known_df = pd.read_csv(Path)
known_df.head()
# Out:
#       idx                   RBS        Name      Rep1      Rep2      Rep3  \
# 0   648.0  TTTAAGAAGGAGATATACAT  RBS_1by1_0  2.482263  2.555338  2.358414
# 1  4096.0  CTTAAGAAGGAGATATACAT  RBS_1by1_1  1.592779  1.694296  1.798210
# 2  4097.0  GTTAAGAAGGAGATATACAT  RBS_1by1_2  0.626302  0.774704  0.947196
# 3  4098.0  ATTAAGAAGGAGATATACAT  RBS_1by1_3  1.696364  1.917735  1.568130
# 4  4099.0  TCTAAGAAGGAGATATACAT  RBS_1by1_4  1.582321  2.118618  1.417531
#
#        Rep4      Rep5      Rep6   AVERAGE  ...  Round  Rep7 Rep8 Rep9  \
# 0  3.102950  2.999178  2.316265  2.635735  ...      0   NaN  NaN  NaN
# 1  1.850738  2.381356  1.996343  1.885620  ...      0   NaN  NaN  NaN
# 2  0.418233  0.532036  0.733023  0.671916  ...      0   NaN  NaN  NaN
# 3  1.600853  1.803056  1.260720  1.641143  ...      0   NaN  NaN  NaN
# 4  2.014216  1.831391  2.186262  1.858390  ...      0   NaN  NaN  NaN
#
#   Unnamed: 19 Unnamed: 20    RBS6  Pred Mean  Pred Std  Pred UCB
# 0         NaN         NaN  AGGAGA        NaN       NaN       NaN
# 1         NaN         NaN  AGGAGA        NaN       NaN       NaN
# 2         NaN         NaN  AGGAGA        NaN       NaN       NaN
# 3         NaN         NaN  AGGAGA        NaN       NaN       NaN
# 4         NaN         NaN  AGGAGA        NaN       NaN       NaN
#
# [5 rows x 26 columns]

# %%
# known_df = known_df[known_df['Group'] != 'bps_noncore']
# known_df.reset_index(inplace=True, drop=True)
# known_df['RBS'] = known_df['RBS6']
# known_df

# %% [markdown]
# ## Conclusion of pipeline
#
# - Data pre-processing: run codes/data_generating.py
#     - log transform
#     - z-score normalisation for each replicate (zero mean and unit variance)
# - Kernel: codes/kernels_for_GPK.py
#     - weighted degree kernel with shift
#     - normalisation: centering; unit variance; normalisation over the whole (train + test) kernel
#     - l = 6 (maximum substring length)
#     - s = 1 (shift)
#     - sigma0 = 1 (signal std)
# - Regression: codes/regression.py
#     - Gaussian Process Regression
#     - train on samples (multi-label) from first round result, i.e. train shape:  (1055, 20)
#     - predict on all design space (4 * 6) except known sequences, i.e. test shape:  (3961, 20)
#     - alpha = 2
# - Recommendation: codes/batch_ucb.py
#     - batch UCB (GP-BUCB)
#     - beta = 2
#     - recommendation size = 90

# %%
rec_size = 90
l = 6
s = 1
beta = 0
alpha = 2
sigma_0 = 1
kernel_name = 'WD_Kernel_Shift'
embedding = 'label'
kernel_norm_flag = True
centering_flag = True
unit_norm_flag = True

# %% [markdown]
# # Top n recommendations
#
# return seuqneces with top n ucb score.

# %%
top_n = Top_n_ucb(known_df, kernel_name=kernel_name, l=l, s=s, sigma_0=sigma_0,
                 embedding=embedding, alpha=alpha, rec_size=rec_size, beta=beta, 
                 kernel_norm_flag=kernel_norm_flag, centering_flag = centering_flag, unit_norm_flag=unit_norm_flag)

# %%
top_known_AVERAGE = top_n.df_known.sort_values(['AVERAGE'], ascending = False).head(90)
top_known_AVERAGE
# Out:
#                        RBS    RBS6   AVERAGE       STD      Group variable  \
# 0     TTTAAGAAGGAGATATACAT  AGGAGA  2.635735  0.334474  Reference     Rep1
# 358   TTTAAGAAGGAGATATACAT  AGGAGA  2.635735  0.334474  Reference     Rep2
# 1790  TTTAAGAAGGAGATATACAT  AGGAGA  2.635735  0.334474  Reference     Rep6
# 1432  TTTAAGAAGGAGATATACAT  AGGAGA  2.635735  0.334474  Reference     Rep5
# 716   TTTAAGAAGGAGATATACAT  AGGAGA  2.635735  0.334474  Reference     Rep3
# ...                    ...     ...       ...       ...        ...      ...
# 1435  ATTAAGAAGGAGATATACAT  AGGAGA  1.641143  0.226911     BPS-NC     Rep5
# 361   ATTAAGAAGGAGATATACAT  AGGAGA  1.641143  0.226911     BPS-NC     Rep2
# 1793  ATTAAGAAGGAGATATACAT  AGGAGA  1.641143  0.226911     BPS-NC     Rep6
# 1077  ATTAAGAAGGAGATATACAT  AGGAGA  1.641143  0.226911     BPS-NC     Rep4
# 715   TTTAAGAAGGAGATATACAT  AGGAGA  1.628994  0.175476  Reference     Rep2
#
#          label  pred mean  pred std
# 0     2.482263   1.189414  0.166621
# 358   2.555338   1.189414  0.166621
# 1790  2.316265   1.189414  0.166621
# 1432  2.999178   1.189414  0.166621
# 716   2.358414   1.189414  0.166621
# ...        ...        ...       ...
# 1435  1.803056   1.336565  0.346506
# 361   1.917735   1.336565  0.346506
# 1793  1.260720   1.336565  0.346506
# 1077  1.600853   1.336565  0.346506
# 715   1.744440   1.189414  0.166621
#
# [90 rows x 9 columns]

# %%
top_n.df_train_test
# Out:
#          AVERAGE      Group        Name      PERC        Plate  Pred Mean  \
# idx
# 648.0   2.635735  Reference  RBS_1by1_0  0.282440  First_Plate        NaN
# 4096.0  1.885620     BPS-NC  RBS_1by1_1  0.285821  First_Plate        NaN
# 4097.0  0.671916     BPS-NC  RBS_1by1_2  0.370243  First_Plate        NaN
# 4098.0  1.641143     BPS-NC  RBS_1by1_3  0.313749  First_Plate        NaN
# 4099.0  1.858390     BPS-NC  RBS_1by1_4  0.216994  First_Plate        NaN
# ...          ...        ...         ...       ...          ...        ...
# 4091.0       NaN        NaN         NaN       NaN          NaN        NaN
# 4084.0       NaN        NaN         NaN       NaN          NaN        NaN
# 4086.0       NaN        NaN         NaN       NaN          NaN        NaN
# 4085.0       NaN        NaN         NaN       NaN          NaN        NaN
# 4087.0       NaN        NaN         NaN       NaN          NaN        NaN
#
#         Pred Std  Pred UCB                   RBS    RBS6  ...  Rep7  Rep8  \
# idx                                                       ...
# 648.0        NaN       NaN  TTTAAGAAGGAGATATACAT  AGGAGA  ...   NaN   NaN
# 4096.0       NaN       NaN  CTTAAGAAGGAGATATACAT  AGGAGA  ...   NaN   NaN
# 4097.0       NaN       NaN  GTTAAGAAGGAGATATACAT  AGGAGA  ...   NaN   NaN
# 4098.0       NaN       NaN  ATTAAGAAGGAGATATACAT  AGGAGA  ...   NaN   NaN
# 4099.0       NaN       NaN  TCTAAGAAGGAGATATACAT  AGGAGA  ...   NaN   NaN
# ...          ...       ...                   ...     ...  ...   ...   ...
# 4091.0       NaN       NaN  TTTAAGATTTTGTTATACAT  TTTTGT  ...   NaN   NaN
# 4084.0       NaN       NaN  TTTAAGATTTTCATATACAT  TTTTCA  ...   NaN   NaN
# 4086.0       NaN       NaN  TTTAAGATTTTCGTATACAT  TTTTCG  ...   NaN   NaN
# 4085.0       NaN       NaN  TTTAAGATTTTCCTATACAT  TTTTCC  ...   NaN   NaN
# 4087.0       NaN       NaN  TTTAAGATTTTCTTATACAT  TTTTCT  ...   NaN   NaN
#
#         Rep9   Replicates  Round       STD  Unnamed: 19  Unnamed: 20  Usable  \
# idx
# 648.0    NaN  1,2,3,4,5,6    0.0  0.334474          NaN          NaN     Yes
# 4096.0   NaN  1,2,3,4,5,6    0.0  0.279010          NaN          NaN     Yes
# 4097.0   NaN  1,2,3,4,5,6    0.0  0.187660          NaN          NaN     Yes
# 4098.0   NaN  1,2,3,4,5,6    0.0  0.226911          NaN          NaN     Yes
# 4099.0   NaN  1,2,3,4,5,6    0.0  0.306855          NaN          NaN     Yes
# ...      ...          ...    ...       ...          ...          ...     ...
# 4091.0   NaN          NaN    NaN       NaN          NaN          NaN     NaN
# 4084.0   NaN          NaN    NaN       NaN          NaN          NaN     NaN
# 4086.0   NaN          NaN    NaN       NaN          NaN          NaN     NaN
# 4085.0   NaN          NaN    NaN       NaN          NaN          NaN     NaN
# 4087.0   NaN          NaN    NaN       NaN          NaN          NaN     NaN
#
#        train_test
# idx
# 648.0       Train
# 4096.0      Train
# 4097.0      Train
# 4098.0      Train
# 4099.0      Train
# ...           ...
# 4091.0       Test
# 4084.0       Test
# 4086.0       Test
# 4085.0       Test
# 4087.0       Test
#
# [4141 rows x 26 columns]

# %%
top_n_rec_df = top_n.run_experiment()
# Out:
# X train shape:  (2147, 20)
# X test shape:  (3783, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg

# %%
top_n_rec_df
# Out:
#                          RBS    RBS6  AVERAGE  pred mean  pred std       ucb  \
# idx
# 2729.0  TTTAAGAGGGGGCTATACAT  GGGGGC      NaN   1.051928  0.486657  1.051928
# 2721.0  TTTAAGAGGGGACTATACAT  GGGGAC      NaN   1.017517  0.425958  1.017517
# 162.0   TTTAAGAAAGGAGTATACAT  AAGGAG      NaN   0.989109  0.455473  0.989109
# 3258.0  TTTAAGATAGTGGTATACAT  TAGTGG      NaN   0.985374  0.474414  0.985374
# 2731.0  TTTAAGAGGGGGTTATACAT  GGGGGT      NaN   0.916163  0.353368  0.916163
# ...                      ...     ...      ...        ...       ...       ...
# 15.0    TTTAAGAAAAATTTATACAT  AAAATT      NaN   0.573114  0.638002  0.573114
# 26.0    TTTAAGAAAACGGTATACAT  AAACGG      NaN   0.572254  0.644076  0.572254
# 185.0   TTTAAGAAAGTGCTATACAT  AAGTGC      NaN   0.567468  0.583124  0.567468
# 16.0    TTTAAGAAAACAATATACAT  AAACAA      NaN   0.567402  0.666212  0.567402
# 502.0   TTTAAGAACTTCGTATACAT  ACTTCG      NaN   0.561831  0.672601  0.561831
#
#              lcb
# idx
# 2729.0  1.051928
# 2721.0  1.017517
# 162.0   0.989109
# 3258.0  0.985374
# 2731.0  0.916163
# ...          ...
# 15.0    0.573114
# 26.0    0.572254
# 185.0   0.567468
# 16.0    0.567402
# 502.0   0.561831
#
# [90 rows x 7 columns]

# %%
plt.hist(top_n.df_design['pred std'])
# Out:
# (array([  8.,  25.,  94., 252., 438., 709., 885., 783., 485., 104.]),
#  array([0.35336821, 0.38860049, 0.42383278, 0.45906506, 0.49429735,
#         0.52952963, 0.56476191, 0.5999942 , 0.63522648, 0.67045877,
#         0.70569105]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(top_n_rec_df['pred std'])
# Out:
# (array([ 4.,  3.,  8., 12., 19., 10.,  6., 15.,  6.,  7.]),
#  array([0.35336821, 0.38609824, 0.41882828, 0.45155831, 0.48428835,
#         0.51701838, 0.54974841, 0.58247845, 0.61520848, 0.64793852,
#         0.68066855]),
#  <a list of 10 Patch objects>)

# %%
kernel_matrix = top_n.gpr.wd_kernel_instance.kernel_all_normalised
plt.imshow(kernel_matrix)
plt.colorbar()

# %% [markdown]
# ## GP-BUCB
#
# Desautels et al. 2014 Algorithm 2
# http://jmlr.org/papers/volume15/desautels14a/desautels14a.pdf

# %%
gpbucb = GP_BUCB(known_df, kernel_name=kernel_name, l=l, s=s,sigma_0=sigma_0,
                 embedding=embedding, alpha=alpha, rec_size=rec_size, beta=beta, 
                 kernel_norm_flag=kernel_norm_flag, centering_flag = centering_flag, unit_norm_flag=unit_norm_flag)

# %%
gpbucb_rec_df = gpbucb.run_experiment()
# Out:
# X train shape:  (2147, 20)
# X test shape:  (3783, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (359, 26)
# X train shape:  (2148, 20)
# X test shape:  (3782, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (360, 26)
# X train shape:  (2149, 20)
# X test shape:  (3781, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (361, 26)
# X train shape:  (2150, 20)
# X test shape:  (3780, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (362, 26)
# X train shape:  (2151, 20)
# X test shape:  (3779, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (363, 26)
# X train shape:  (2152, 20)
# X test shape:  (3778, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (364, 26)
# X train shape:  (2153, 20)
# X test shape:  (3777, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (365, 26)
# X train shape:  (2154, 20)
# X test shape:  (3776, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (366, 26)
# X train shape:  (2155, 20)
# X test shape:  (3775, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (367, 26)
# X train shape:  (2156, 20)
# X test shape:  (3774, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (368, 26)
# X train shape:  (2157, 20)
# X test shape:  (3773, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (369, 26)
# X train shape:  (2158, 20)
# X test shape:  (3772, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (370, 26)
# X train shape:  (2159, 20)
# X test shape:  (3771, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (371, 26)
# X train shape:  (2160, 20)
# X test shape:  (3770, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (372, 26)
# X train shape:  (2161, 20)
# X test shape:  (3769, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (373, 26)
# X train shape:  (2162, 20)
# X test shape:  (3768, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (374, 26)
# X train shape:  (2163, 20)
# X test shape:  (3767, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (375, 26)
# X train shape:  (2164, 20)
# X test shape:  (3766, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (376, 26)
# X train shape:  (2165, 20)
# X test shape:  (3765, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (377, 26)
# X train shape:  (2166, 20)
# X test shape:  (3764, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (378, 26)
# X train shape:  (2167, 20)
# X test shape:  (3763, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (379, 26)
# X train shape:  (2168, 20)
# X test shape:  (3762, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (380, 26)
# X train shape:  (2169, 20)
# X test shape:  (3761, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (381, 26)
# X train shape:  (2170, 20)
# X test shape:  (3760, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (382, 26)
# X train shape:  (2171, 20)
# X test shape:  (3759, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (383, 26)
# X train shape:  (2172, 20)
# X test shape:  (3758, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (384, 26)
# X train shape:  (2173, 20)
# X test shape:  (3757, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (385, 26)
# X train shape:  (2174, 20)
# X test shape:  (3756, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (386, 26)
# X train shape:  (2175, 20)
# X test shape:  (3755, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (387, 26)
# X train shape:  (2176, 20)
# X test shape:  (3754, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (388, 26)
# X train shape:  (2177, 20)
# X test shape:  (3753, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (389, 26)
# X train shape:  (2178, 20)
# X test shape:  (3752, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (390, 26)
# X train shape:  (2179, 20)
# X test shape:  (3751, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (391, 26)
# X train shape:  (2180, 20)
# X test shape:  (3750, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (392, 26)
# X train shape:  (2181, 20)
# X test shape:  (3749, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (393, 26)
# X train shape:  (2182, 20)
# X test shape:  (3748, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (394, 26)
# X train shape:  (2183, 20)
# X test shape:  (3747, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (395, 26)
# X train shape:  (2184, 20)
# X test shape:  (3746, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (396, 26)
# X train shape:  (2185, 20)
# X test shape:  (3745, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (397, 26)
# X train shape:  (2186, 20)
# X test shape:  (3744, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (398, 26)
# X train shape:  (2187, 20)
# X test shape:  (3743, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (399, 26)
# X train shape:  (2188, 20)
# X test shape:  (3742, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (400, 26)
# X train shape:  (2189, 20)
# X test shape:  (3741, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (401, 26)
# X train shape:  (2190, 20)
# X test shape:  (3740, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (402, 26)
# X train shape:  (2191, 20)
# X test shape:  (3739, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (403, 26)
# X train shape:  (2192, 20)
# X test shape:  (3738, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (404, 26)
# X train shape:  (2193, 20)
# X test shape:  (3737, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (405, 26)
# X train shape:  (2194, 20)
# X test shape:  (3736, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (406, 26)
# X train shape:  (2195, 20)
# X test shape:  (3735, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (407, 26)
# X train shape:  (2196, 20)
# X test shape:  (3734, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (408, 26)
# X train shape:  (2197, 20)
# X test shape:  (3733, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (409, 26)
# X train shape:  (2198, 20)
# X test shape:  (3732, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (410, 26)
# X train shape:  (2199, 20)
# X test shape:  (3731, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (411, 26)
# X train shape:  (2200, 20)
# X test shape:  (3730, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (412, 26)
# X train shape:  (2201, 20)
# X test shape:  (3729, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (413, 26)
# X train shape:  (2202, 20)
# X test shape:  (3728, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (414, 26)
# X train shape:  (2203, 20)
# X test shape:  (3727, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (415, 26)
# X train shape:  (2204, 20)
# X test shape:  (3726, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (416, 26)
# X train shape:  (2205, 20)
# X test shape:  (3725, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (417, 26)
# X train shape:  (2206, 20)
# X test shape:  (3724, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (418, 26)
# X train shape:  (2207, 20)
# X test shape:  (3723, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (419, 26)
# X train shape:  (2208, 20)
# X test shape:  (3722, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (420, 26)
# X train shape:  (2209, 20)
# X test shape:  (3721, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (421, 26)
# X train shape:  (2210, 20)
# X test shape:  (3720, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (422, 26)
# X train shape:  (2211, 20)
# X test shape:  (3719, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (423, 26)
# X train shape:  (2212, 20)
# X test shape:  (3718, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (424, 26)
# X train shape:  (2213, 20)
# X test shape:  (3717, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (425, 26)
# X train shape:  (2214, 20)
# X test shape:  (3716, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (426, 26)
# X train shape:  (2215, 20)
# X test shape:  (3715, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (427, 26)
# X train shape:  (2216, 20)
# X test shape:  (3714, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (428, 26)
# X train shape:  (2217, 20)
# X test shape:  (3713, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (429, 26)
# X train shape:  (2218, 20)
# X test shape:  (3712, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (430, 26)
# X train shape:  (2219, 20)
# X test shape:  (3711, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (431, 26)
# X train shape:  (2220, 20)
# X test shape:  (3710, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (432, 26)
# X train shape:  (2221, 20)
# X test shape:  (3709, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (433, 26)
# X train shape:  (2222, 20)
# X test shape:  (3708, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (434, 26)
# X train shape:  (2223, 20)
# X test shape:  (3707, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (435, 26)
# X train shape:  (2224, 20)
# X test shape:  (3706, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (436, 26)
# X train shape:  (2225, 20)
# X test shape:  (3705, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (437, 26)
# X train shape:  (2226, 20)
# X test shape:  (3704, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (438, 26)
# X train shape:  (2227, 20)
# X test shape:  (3703, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (439, 26)
# X train shape:  (2228, 20)
# X test shape:  (3702, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (440, 26)
# X train shape:  (2229, 20)
# X test shape:  (3701, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (441, 26)
# X train shape:  (2230, 20)
# X test shape:  (3700, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (442, 26)
# X train shape:  (2231, 20)
# X test shape:  (3699, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (443, 26)
# X train shape:  (2232, 20)
# X test shape:  (3698, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (444, 26)
# X train shape:  (2233, 20)
# X test shape:  (3697, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (445, 26)
# X train shape:  (2234, 20)
# X test shape:  (3696, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (446, 26)
# X train shape:  (2235, 20)
# X test shape:  (3695, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (447, 26)
# X train shape:  (2236, 20)
# X test shape:  (3694, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg
# train size  (448, 26)
# X train shape:  (2237, 20)
# X test shape:  (3693, 20)
# create kernel instance
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# finish creating kernel instance
# gp_reg fit
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# wds_l6_sigma0_1_s1_center_True_unitnorm_True
# Load saved kernel matrix...
# gp_reg pred
# finish reg

# %% [markdown]
# ## Recommendation results

# %%
gpbucb_rec_df
# Out:
#                          RBS    RBS6  AVERAGE  pred mean  pred std       ucb  \
# idx
# 2729.0  TTTAAGAGGGGGCTATACAT  GGGGGC      NaN   1.051928  0.486657  1.051928
# 2721.0  TTTAAGAGGGGACTATACAT  GGGGAC      NaN   1.017517  0.425420  1.017517
# 162.0   TTTAAGAAAGGAGTATACAT  AAGGAG      NaN   0.989109  0.455444  0.989109
# 3258.0  TTTAAGATAGTGGTATACAT  TAGTGG      NaN   0.985374  0.474377  0.985374
# 2731.0  TTTAAGAGGGGGTTATACAT  GGGGGT      NaN   0.916163  0.350266  0.916163
# ...                      ...     ...      ...        ...       ...       ...
# 15.0    TTTAAGAAAAATTTATACAT  AAAATT      NaN   0.573114  0.550503  0.573114
# 26.0    TTTAAGAAAACGGTATACAT  AAACGG      NaN   0.572254  0.561592  0.572254
# 185.0   TTTAAGAAAGTGCTATACAT  AAGTGC      NaN   0.567468  0.539113  0.567468
# 16.0    TTTAAGAAAACAATATACAT  AAACAA      NaN   0.567402  0.595323  0.567402
# 502.0   TTTAAGAACTTCGTATACAT  ACTTCG      NaN   0.561831  0.602760  0.561831
#
#              lcb
# idx
# 2729.0  1.051928
# 2721.0  1.017517
# 162.0   0.989109
# 3258.0  0.985374
# 2731.0  0.916163
# ...          ...
# 15.0    0.573114
# 26.0    0.572254
# 185.0   0.567468
# 16.0    0.567402
# 502.0   0.561831
#
# [90 rows x 7 columns]

# %%
top_n_rec_df
# Out:
#                          RBS    RBS6  AVERAGE  pred mean  pred std       ucb  \
# idx
# 2729.0  TTTAAGAGGGGGCTATACAT  GGGGGC      NaN   1.051928  0.486657  1.051928
# 2721.0  TTTAAGAGGGGACTATACAT  GGGGAC      NaN   1.017517  0.425958  1.017517
# 162.0   TTTAAGAAAGGAGTATACAT  AAGGAG      NaN   0.989109  0.455473  0.989109
# 3258.0  TTTAAGATAGTGGTATACAT  TAGTGG      NaN   0.985374  0.474414  0.985374
# 2731.0  TTTAAGAGGGGGTTATACAT  GGGGGT      NaN   0.916163  0.353368  0.916163
# ...                      ...     ...      ...        ...       ...       ...
# 15.0    TTTAAGAAAAATTTATACAT  AAAATT      NaN   0.573114  0.638002  0.573114
# 26.0    TTTAAGAAAACGGTATACAT  AAACGG      NaN   0.572254  0.644076  0.572254
# 185.0   TTTAAGAAAGTGCTATACAT  AAGTGC      NaN   0.567468  0.583124  0.567468
# 16.0    TTTAAGAAAACAATATACAT  AAACAA      NaN   0.567402  0.666212  0.567402
# 502.0   TTTAAGAACTTCGTATACAT  ACTTCG      NaN   0.561831  0.672601  0.561831
#
#              lcb
# idx
# 2729.0  1.051928
# 2721.0  1.017517
# 162.0   0.989109
# 3258.0  0.985374
# 2731.0  0.916163
# ...          ...
# 15.0    0.573114
# 26.0    0.572254
# 185.0   0.567468
# 16.0    0.567402
# 502.0   0.561831
#
# [90 rows x 7 columns]

# %%
top_n_rec_df.index
# Out:
# Float64Index([2729.0, 2721.0,  162.0, 3258.0, 2731.0, 2657.0,  186.0, 3233.0,
#               2733.0, 2720.0,  627.0, 2662.0, 2661.0, 2234.0, 2746.0, 2669.0,
#               2732.0,  161.0, 2672.0, 2210.0, 2668.0,   49.0, 2440.0, 2725.0,
#               1416.0, 2656.0, 2734.0,  497.0, 2186.0,  634.0, 2726.0,   25.0,
#                674.0,  394.0,  610.0, 3253.0,  138.0,  609.0, 1442.0,  418.0,
#                698.0, 2805.0, 3232.0, 2170.0, 1674.0, 2801.0, 2810.0, 3257.0,
#               2680.0,  682.0, 3208.0,   51.0,  496.0, 2806.0, 3254.0, 2665.0,
#                673.0, 2800.0, 1705.0,   14.0,   27.0,  930.0,   58.0, 1697.0,
#                160.0,   48.0,  501.0,  681.0,  181.0, 3235.0, 2809.0, 3687.0,
#                499.0,   12.0, 2670.0, 2209.0,  614.0, 2741.0, 2977.0,  613.0,
#               1184.0, 3681.0,  241.0,   19.0,   10.0,   15.0,   26.0,  185.0,
#                 16.0,  502.0],
#              dtype='float64', name='idx')

# %% [markdown]
# ### Similarity between recommendations
#
# characterized by the same kernel used for prediction.

# %%
num_rows = 2
num_cols = 3

wd_kernel = WD_Shift_Kernel
fig,a = plt.subplots(num_rows, num_cols, figsize = (15,10))

wd_kernel.INIT_FLAG = False
im = a[0][0].imshow(top_n.gpr.wd_kernel_instance.__call__(np.asarray(top_n_rec_df['RBS'])), cmap = 'viridis')
fig.colorbar(im, ax =a[0][0])
a[0][0].set_title('Top n sequences kernel matrix, sorted by ucb')

wd_kernel.INIT_FLAG = False
im = a[0][1].imshow(gpbucb.gpr.wd_kernel_instance.__call__(np.asarray(gpbucb_rec_df['RBS'])), cmap = 'viridis')
fig.colorbar(im, ax =a[0][1])
a[0][1].set_title('GP-BUCB sequences kernel matrix, sorted by ucb')

# wd_kernel.INIT_FLAG = False
# all_features = np.concatenate((np.asarray(top_n_rec_df['RBS']), np.asarray(gpbucb_rec_df['RBS'])), axis = 0)
# im = a[0][2].imshow(wd_kernel(l=6, features = all_features).kernel_all_normalised, cmap = 'viridis')
# fig.colorbar(im, ax =a[0][2])
# a[0][2].set_title('Top n + GP-BUCB')

im = a[1][0].hist(top_n_rec_df['ucb'])
a[1][0].set_title('top n hist')

im = a[1][1].hist(gpbucb_rec_df['ucb'])
a[1][1].set_title('GP_BUCB hist')

# im = a[1][2].hist(gpbucb_rec_df['ucb'])
# a[1][2].set_title('GP_BUCB hist')
# Out:
# Text(0.5, 1.0, 'GP_BUCB hist')

# %%
common_rec = set(top_n_rec_df['RBS']).intersection(set(gpbucb_rec_df['RBS']))
print('Number of intersection of recommendations: ', len(common_rec))
# Out:
# Number of intersection of recommendations:  90

# %%
para_name = 'alpha' + str(alpha) + '_beta' + str(beta) 
#+ 'kernelNorm' + str(kernel_norm_flag)

with pd.ExcelWriter('batch_ucb.xlsx', engine="openpyxl", mode='a') as writer:
    top_n_rec_df.to_excel(writer, sheet_name = 'top_n_core_' + para_name)
    gpbucb_rec_df.to_excel(writer, sheet_name = 'gpbucb_core_' + para_name)

# %%
# batch_ucb = pd.read_excel(open('batch_ucb.xlsx', 'rb'), sheet_name=None)
# batch_ucb_copy = pd.read_excel(open('batch_ucb_copy.xlsx', 'rb'), sheet_name=None)

# for key in batch_ucb.keys():
#     assert (batch_ucb[key]['RBS'] == batch_ucb_copy[key]['RBS']).all()
